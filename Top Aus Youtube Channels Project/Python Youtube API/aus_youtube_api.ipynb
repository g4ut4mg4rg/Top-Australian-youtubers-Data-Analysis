# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
api_key='AIzaSyCCUS9q9QIeNuCiO_r9fdgqy6kHU2y0Wwc'

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key
)

request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id="UC_x5XG1OV2P6uZZ5FSM9Ttw"
)
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'kG5DaDqAgg0R9jiG-PbueuLo-vw', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'UeOVSXKssiBOegVc77GaDdXy2MU', 'id': 'UC_x5XG1OV2P6uZZ5FSM9Ttw', 'snippet': {'title': 'Google for Developers', 'description': 'Subscribe to join a community of creative developers and learn the latest in Google technology — from AI and cloud, to mobile and web.\n\nExplore more at developers.google.com\n\n', 'customUrl': '@googledevelopers', 'publishedAt': '2007-08-23T00:34:43Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/vY3uYs71A_JwVcigyd2tVRHwuj05_cYktQSuzRCxta-9VFxHFtKjGrwG9WFi8ijXITBL3CwPQQ=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/vY3uYs71A_JwVcigyd2tVRHwuj05_cYktQSuzRCxta-9VFxHFtKjGrwG9WFi8ijXITBL3CwPQQ=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/vY3uYs71A_JwVcigyd2tVRHwuj05_cYktQS
# ...

# %%
from googleapiclient.discovery import build


# Create a build object
youtube = build('youtube', 'v3', developerKey=api_key)

# Function to get channel IDs of popular videos
def get_top_channels(region_code='AU', max_results=100):
    channels = set()
    next_page_token = None

    while len(channels) < max_results:
        # Fetch popular videos
        request = youtube.videos().list(
            part='snippet',
            chart='mostPopular',
            regionCode=region_code,
            maxResults=50,
            pageToken=next_page_token
        )
        response = request.execute()
        
        for item in response['items']:
            channels.add(item['snippet']['channelId'])
            if len(channels) >= max_results:
                break
        
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

    return list(channels)

# Get the top 100 Australian YouTube channel IDs
top_channels = get_top_channels(max_results=100)

# Display the channel IDs
for idx, channel_id in enumerate(top_channels, start=1):
    print(f"{idx}: {channel_id}")
    """request = youtube.channels().list(
        part="snippet,statistics", #"snippet,contentDetails,statistics"
        id=channel_id
    )
    response = request.execute()
    print(response)"""
# Out:
# 1: UCwVg9btOceLQuNCdoQk9CXg
# 2: UC4-CH0epzZpD_ARhxCx6LaQ
# 3: UCSnqXeK94-iNmwqGO__eJ5g
# 4: UC7_gcs09iThXybpVgjHZ_7g
# 5: UCYDmx2Sfpnaxg488yBpZIGg
# 6: UCwh2SF7McSUf1GVFVk0nP8w
# 7: UCR9Gcq0CMm6YgTzsDxAxjOQ
# 8: UCpx2BZg8ABgaDV50sGJtWAg
# 9: UCZ8TREbPfawhSvayVe5pqKg
# 10: UCOSIXyYdT93OzpRnAuWaKjQ
# 11: UCxOzbkk0bdVl6-tH1Fcajfg
# 12: UCJsfO4nKS3_c24zLbF8rT0A
# 13: UCeKLuqGciqZZ5RFYk5CbqXg
# 14: UCaoTOpfjVfdm_XlYvwbVicQ
# 15: UC94XlnLwRY7AP1GhbfbAcYQ
# 16: UCddiUEpeqJcYeBxX1IVBKvQ
# 17: UCad_KQumqRY06gpb24HkpPw
# 18: UCoYOlthN2PmOIGhmSEcp6oA
# 19: UCm9SZAl03Rev9sFwloCdz1g
# 20: UCnUYyAtDiyeaobSzKqVE_BA
# 21: UCKrdjiuS66yXOdEZ_cOD_TA
# 22: UCQJWtTnAHhEG5w4uN0udnUQ
# 23: UC4zWG9LccdWGUlF77LZ8toA
# 24: UC7R27sAWc_DqOldtI1JcYhQ
# 25: UCz97F7dMxBNOfGYu3rx8aCw
# 26: UCjYO25ZVJT523TD1iYHzcbw
# 27: UCVYamHliCI9rw1tHR1xbkfw
# 28: UClu2e7S8atp6tG2galK9hgg
# 29: UCAHufvd02viJSRdt3ojdPOg
# 30: UCgJRL30YS6XFxq9Ga8W2J3A
# 31: UC7_YxT-KID8kRbqZo7MyscQ
# 32: UCpeRshJCY2B1irGJUs3vmRg
# ...

# %%
# from googleapiclient.discovery import build

# api_key = 'AIzaSyCCUS9q9QIeNuCiO_r9fdgqy6kHU2y0Wwc'

# youtube = build('youtube', 'v3', developerKey=api_key)

# # List of known popular Australian YouTube channel IDs
# # This list should be populated with actual Australian channel IDs
# # You may need to curate this list manually or use an external data source
# popular_au_channel_ids = [
#     'UCq-Fj5jknLsUf-MWSy4_brA',  # T-Series
#     'UC-lHJZR3Gqxm24_Vd_AJ5Yw',  # PewDiePie
#     'UCpEhnqL0y41EpW2TvWAHD7Q',  # 5-Minute Crafts
#     # Add more channel IDs here...
# ]

# # Function to get channel statistics
# def get_channel_stats(channel_ids):
#     stats = []
#     for i in range(0, len(channel_ids), 50):  # YouTube API allows max 50 channels per request
#         request = youtube.channels().list(
#             part='snippet,statistics',
#             id=','.join(channel_ids[i:i+50])
#         )
#         response = request.execute()
#         stats.extend(response['items'])
#     return stats

# # Get statistics for the channels
# channel_stats = get_channel_stats(popular_au_channel_ids)

# # Sort the channels by subscriber count
# sorted_channels = sorted(channel_stats, key=lambda x: int(x['statistics']['subscriberCount']), reverse=True)

# # Get top 100 channels
# top_100_channels = sorted_channels[:100]

# # Display the channel IDs and their subscriber counts
# for idx, channel in enumerate(top_100_channels, start=1):
#     channel_id = channel['id']
#     channel_title = channel['snippet']['title']
#     subscriber_count = channel['statistics']['subscriberCount']
#     print(f"{idx}: {channel_title} ({channel_id}) - {subscriber_count} subscribers")
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7816\3947007521.py in <module>
#      30
#      31 # Get statistics for the channels
# ---> 32 channel_stats = get_channel_stats(popular_au_channel_ids)
#      33
#      34 # Sort the channels by subscriber count
#
# ~\AppData\Local\Temp\ipykernel_7816\3947007521.py in get_channel_stats(channel_ids)
#      25             id=','.join(channel_ids[i:i+50])
#      26         )
# ---> 27         response = request.execute()
#      28         stats.extend(response['items'])
#      29     return stats
#
# ~\anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
# ...

# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyCCUS9q9QIeNuCiO_r9fdgqy6kHU2y0Wwc'

# Create a build object
youtube = build('youtube', 'v3', developerKey=api_key)

# List of Australian YouTube channel names
channel_names = [
    'Bounce Patrol - Kids Songs',
    'Chloe Ting',
    'LazarBeam',
    'How Ridiculous',
    'CKN',
    'HowToBasic',
    'Lachlan',
    'SR Toys Collection',
    'Primitive Technology',
    'AC/DC',
    'JoshDub',
    'Jiemba Sands',
    'GLITCH',
    'EYstreem',
    'Hillsong Worship',
    'cricket.com.au',
    'KjraGaming',
    'Muselk',
    'VuJae',
    'James Condy',
    'The Rybka Twins',
    'NickandCarrie',
    'Troye Sivan',
    'SMG4',
    'Fresh',
    'YBS Youngbloods',
    'Hebbars Kitchen',
    'The Mik Maks',
    'The Norris Nuts',
    'XtremeGamez',
    'YL Toys Collection',
    'RackaRacka',
    'Come And Play',
    'x2Twins',
    'Strawberry Jam Toys',
    'HighlightsNepal',
    'Ozzy Man Reviews',
    'mmmEnglish',
    'Nadeem Sarwar',
    'Mully',
    'Saksham Magic',
    'Meditative Mind',
    '60 Minutes Australia',
    'PD',
    'Priya and Sid',
    'Tones And I',
    'Fitz',
    'I did a thing',
    'Hillsong UNITED',
    'How To Cook That',
    'Sam Fricker',
    'Iggy Azalea Music VEVO',
    'ColdFusion',
    'Prestige Clips',
    'WadZee',
    'Moto Madness',
    'Jalals',
    'Andy Cooks',
    'Loserfruit',
    'LazarLazar',
    'TwoSetViolin',
    'Sticky',
    'Lyanna Kea',
    'Fluffy Jet Toys',
    'Sky News Australia',
    'Internet Historian',
    'SunnyV2',
    'lozaus1',
    'Mighty Car Mods',
    'Junpei Zaki',
    'Sheet Music Boss',
    'Sam Green',
    'Tina Yong',
    'Vindooly',
    'Halfbrick Studios',
    'The Wiggles - Kids Songs and Nursery Rhymes!',
    'LT.LICKME',
    'Funformi',
    'Grace\'s World',
    'Ash Magic',
    'superwog1',
    'Wolfychu',
    'Kyutie',
    'Slapped Ham',
    'Lauren Curtis',
    'Jason Stephenson - Sleep Meditation Music',
    'ArtSpear Entertainment',
    'EmKay',
    'Saint',
    'Ben Lionel Scott',
    'Code Bullet',
    'Vin',
    'Ryan Williams',
    'MyCupcakeAddiction',
    'maxmoefoe',
    'HeyImBee',
    'Tommy Craze',
    'VaatiVidya',
    'Blender Guru',
    'Kawaii Kunicorn'
]

# Function to get channel ID from channel name
def get_channel_id(channel_name):
    request = youtube.search().list(
        part='snippet',
        q=channel_name,
        type='channel',
        maxResults=1
    )
    response = request.execute()
    return response['items'][0]['snippet']['channelId']

# Function to get channel statistics
def get_channel_stats(channel_ids):
    stats = []
    for i in range(0, len(channel_ids), 50):  # YouTube API allows max 50 channels per request
        request = youtube.channels().list(
            part='snippet,statistics',
            id=','.join(channel_ids[i:i+50])
        )
        response = request.execute()
        stats.extend(response['items'])
    return stats

# Get channel IDs for the provided channel names
channel_ids = [get_channel_id(name) for name in channel_names]

# Get statistics for the channels
channel_stats = get_channel_stats(channel_ids)

# Sort the channels by subscriber count
sorted_channels = sorted(channel_stats, key=lambda x: int(x['statistics']['subscriberCount']), reverse=True)

# Get top 100 channels
top_100_channels = sorted_channels[:100]

# Display the channel IDs and their subscriber counts
for idx, channel in enumerate(top_100_channels, start=1):
    channel_id = channel['id']
    channel_title = channel['snippet']['title']
    subscriber_count = channel['statistics']['subscriberCount']
    view_count = channel['statistics']['viewCount']
    video_count = channel['statistics']['videoCount']
    print(f"{idx}: {channel_title} ({channel_id}) - {subscriber_count} subscribers, {view_count} views, {video_count} videos")
# Out:
# 1: Bounce Patrol - Kids Songs (UC56cowXhoqRWHeqfSJkIQaA) - 29100000 subscribers, 22391924134 views, 370 videos
# 2: Chloe Ting (UCCgLoMYIyP0U56dEhEL1wXQ) - 25200000 subscribers, 3174361465 views, 438 videos
# 3: LazarBeam (UCw1SQ6QRRtfAhrN_cjkrOgA) - 21900000 subscribers, 9387336858 views, 1343 videos
# 4: How Ridiculous (UC5f5IV0Bf79YLp_p9nfInRA) - 21400000 subscribers, 12231962262 views, 717 videos
# 5: CKN  (UCfaZw8XH_zmAVkBst_MPD6w) - 18800000 subscribers, 12793605160 views, 492 videos
# 6: HowToBasic (UCR4s1DE9J4DHzZYXMltSMAg) - 17500000 subscribers, 3821764981 views, 611 videos
# 7: Lachlan (UCh7EqOZt7EvO2osuKbIlpGg) - 15100000 subscribers, 5536240037 views, 3906 videos
# 8: SR Toys Collection (UCFVWgnyVpfvjFOjVz-sSXMw) - 12100000 subscribers, 4047877313 views, 984 videos
# 9: Primitive Technology (UCAL3JXZSzSm8AlZyD3nQdBA) - 10900000 subscribers, 1139558706 views, 78 videos
# 10: AC/DC (UCB0JSO6d5ysH2Mmqz5I9rIw) - 10500000 subscribers, 9569486342 views, 196 videos
# ...

# %%
# from googleapiclient.discovery import build
# import pandas as pd

# # Your API key here
# api_key = 'AIzaSyCCUS9q9QIeNuCiO_r9fdgqy6kHU2y0Wwc'

# # Create a build object
# youtube = build('youtube', 'v3', developerKey=api_key)

# # List of Australian YouTube channel names
# channel_names = [
#     'Bounce Patrol - Kids Songs',
#     'Chloe Ting',
#     'LazarBeam',
#     'How Ridiculous',
#     'CKN',
#     'HowToBasic',
#     'Lachlan',
#     'SR Toys Collection',
#     'Primitive Technology',
#     'AC/DC',
#     'JoshDub',
#     'Jiemba Sands',
#     'GLITCH',
#     'EYstreem',
#     'Hillsong Worship',
#     'cricket.com.au',
#     'KjraGaming',
#     'Muselk',
#     'VuJae',
#     'James Condy',
#     'The Rybka Twins',
#     'NickandCarrie',
#     'Troye Sivan',
#     'SMG4',
#     'Fresh',
#     'YBS Youngbloods',
#     'Hebbars Kitchen',
#     'The Mik Maks',
#     'The Norris Nuts',
#     'XtremeGamez',
#     'YL Toys Collection',
#     'RackaRacka',
#     'Come And Play',
#     'x2Twins',
#     'Strawberry Jam Toys',
#     'HighlightsNepal',
#     'Ozzy Man Reviews',
#     'mmmEnglish',
#     'Nadeem Sarwar',
#     'Mully',
#     'Saksham Magic',
#     'Meditative Mind',
#     '60 Minutes Australia',
#     'PD',
#     'Priya and Sid',
#     'Tones And I',
#     'Fitz',
#     'I did a thing',
#     'Hillsong UNITED',
#     'How To Cook That',
#     'Sam Fricker',
#     'Iggy Azalea Music VEVO',
#     'ColdFusion',
#     'Prestige Clips',
#     'WadZee',
#     'Moto Madness',
#     'Jalals',
#     'Andy Cooks',
#     'Loserfruit',
#     'LazarLazar',
#     'TwoSetViolin',
#     'Sticky',
#     'Lyanna Kea',
#     'Fluffy Jet Toys',
#     'Sky News Australia',
#     'Internet Historian',
#     'SunnyV2',
#     'lozaus1',
#     'Mighty Car Mods',
#     'Junpei Zaki',
#     'Sheet Music Boss',
#     'Sam Green',
#     'Tina Yong',
#     'Vindooly',
#     'Halfbrick Studios',
#     'The Wiggles - Kids Songs and Nursery Rhymes!',
#     'LT.LICKME',
#     'Funformi',
#     'Grace\'s World',
#     'Ash Magic',
#     'superwog1',
#     'Wolfychu',
#     'Kyutie',
#     'Slapped Ham',
#     'Lauren Curtis',
#     'Jason Stephenson - Sleep Meditation Music',
#     'ArtSpear Entertainment',
#     'EmKay',
#     'Saint',
#     'Ben Lionel Scott',
#     'Code Bullet',
#     'Vin',
#     'Ryan Williams',
#     'MyCupcakeAddiction',
#     'maxmoefoe',
#     'HeyImBee',
#     'Tommy Craze',
#     'VaatiVidya',
#     'Blender Guru',
#     'Kawaii Kunicorn'
# ]

# # Function to get channel ID from channel name
# def get_channel_id(channel_name):
#     request = youtube.search().list(
#         part='snippet',
#         q=channel_name,
#         type='channel',
#         maxResults=1
#     )
#     response = request.execute()
#     return response['items'][0]['snippet']['channelId']

# # Function to get channel statistics
# def get_channel_stats(channel_ids):
#     stats = []
#     for i in range(0, len(channel_ids), 50):  # YouTube API allows max 50 channels per request
#         request = youtube.channels().list(
#             part='snippet,statistics',
#             id=','.join(channel_ids[i:i+50])
#         )
#         response = request.execute()
#         stats.extend(response['items'])
#     return stats

# # Get channel IDs for the provided channel names
# channel_ids = [get_channel_id(name) for name in channel_names]

# # Get statistics for the channels
# channel_stats = get_channel_stats(channel_ids)

# # Sort the channels by subscriber count
# sorted_channels = sorted(channel_stats, key=lambda x: int(x['statistics']['subscriberCount']), reverse=True)

# # Get top 100 channels
# top_100_channels = sorted_channels[:100]

# # Prepare data for DataFrame
# data = []
# for idx, channel in enumerate(top_100_channels, start=1):
#     channel_id = channel['id']
#     channel_title = channel['snippet']['title']
#     subscriber_count = channel['statistics']['subscriberCount']
#     view_count = channel['statistics']['viewCount']
#     video_count = channel['statistics']['videoCount']
#     data.append([idx, channel_title, channel_id, subscriber_count, view_count, video_count])

# # Create a DataFrame
# df = pd.DataFrame(data, columns=['Rank', 'Channel Title', 'Channel ID', 'Subscribers', 'Views', 'Videos'])

# # Print the DataFrame
# print(df)

# # Export the DataFrame to an Excel file
# df.to_excel('top_100_australian_youtube_channels.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7816\227181083.py in <module>
#     136
#     137 # Get channel IDs for the provided channel names
# --> 138 channel_ids = [get_channel_id(name) for name in channel_names]
#     139
#     140 # Get statistics for the channels
#
# ~\AppData\Local\Temp\ipykernel_7816\227181083.py in <listcomp>(.0)
#     136
#     137 # Get channel IDs for the provided channel names
# --> 138 channel_ids = [get_channel_id(name) for name in channel_names]
#     139
#     140 # Get statistics for the channels
#
# ~\AppData\Local\Temp\ipykernel_7816\227181083.py in get_channel_id(channel_name)
#     120         maxResults=1
#     121     )
# --> 122     response = request.execute()
#     123     return response['items'][0]['snippet']['channelId']
#     124
#
# ...

# %%
#To convert the provided data into a table and export it to an Excel file, we'll use the `pandas` library in Python. Here's the complete code to achieve this:
import os

# Data as a list of dictionaries
data = [
    {"Rank": 1, "Channel Title": "Bounce Patrol - Kids Songs", "Channel ID": "UC56cowXhoqRWHeqfSJkIQaA", "Subscribers": 29100000, "Views": 22391924134, "Videos": 370},
    {"Rank": 2, "Channel Title": "Chloe Ting", "Channel ID": "UCCgLoMYIyP0U56dEhEL1wXQ", "Subscribers": 25200000, "Views": 3174361465, "Videos": 438},
    {"Rank": 3, "Channel Title": "LazarBeam", "Channel ID": "UCw1SQ6QRRtfAhrN_cjkrOgA", "Subscribers": 21900000, "Views": 9387336858, "Videos": 1343},
    {"Rank": 4, "Channel Title": "How Ridiculous", "Channel ID": "UC5f5IV0Bf79YLp_p9nfInRA", "Subscribers": 21400000, "Views": 12231962262, "Videos": 717},
    {"Rank": 5, "Channel Title": "CKN", "Channel ID": "UCfaZw8XH_zmAVkBst_MPD6w", "Subscribers": 18800000, "Views": 12793605160, "Videos": 492},
    {"Rank": 6, "Channel Title": "HowToBasic", "Channel ID": "UCR4s1DE9J4DHzZYXMltSMAg", "Subscribers": 17500000, "Views": 3821764981, "Videos": 611},
    {"Rank": 7, "Channel Title": "Lachlan", "Channel ID": "UCh7EqOZt7EvO2osuKbIlpGg", "Subscribers": 15100000, "Views": 5536240037, "Videos": 3906},
    {"Rank": 41, "Channel Title": "Saksham Magic", "Channel ID": "UCVxR8M2OeHf4BdKzzzpz83A", "Subscribers": 5750000, "Views": 5914282779, "Videos": 2091},
    {"Rank": 42, "Channel Title": "Meditative Mind", "Channel ID": "UCM0YvsRfYfsniGAhjvYFOSA", "Subscribers": 5690000, "Views": 1388540751, "Videos": 1733},
    {"Rank": 43, "Channel Title": "60 Minutes Australia", "Channel ID": "UC0L1suV8pVgO4pCAIBNGx5w", "Subscribers": 5670000, "Views": 2156395667, "Videos": 4269},
    {"Rank": 44, "Channel Title": "Priya and Sid", "Channel ID": "UCsbFefxpne9aYgoQ7baNnRg", "Subscribers": 5430000, "Views": 2180618929, "Videos": 444},
    {"Rank": 45, "Channel Title": "Tones And I", "Channel ID": "UCQeiBlCcS4-XGwFjrvDn96w", "Subscribers": 5390000, "Views": 3025929402, "Videos": 153},
    {"Rank": 46, "Channel Title": "Fitz", "Channel ID": "UCtb8P4rf_1n8KS8eZk_lNNw", "Subscribers": 5290000, "Views": 701819064, "Videos": 157},
    {"Rank": 47, "Channel Title": "I did a thing", "Channel ID": "UCJLZe_NoiG0hT7QCX_9vmqw", "Subscribers": 5110000, "Views": 705107369, "Videos": 111},
    {"Rank": 48, "Channel Title": "Hillsong UNITED", "Channel ID": "UCsOoQeBWPnfWBYAwmO795zg", "Subscribers": 5080000, "Views": 1915476623, "Videos": 543},
    {"Rank": 49, "Channel Title": "How To Cook That", "Channel ID": "UCsP7Bpw36J666Fct5M8u-ZA", "Subscribers": 4950000, "Views": 941009178, "Videos": 524},
    {"Rank": 50, "Channel Title": "Sam Fricker", "Channel ID": "UC7Lzxasu-1yxVks_pr1p10g", "Subscribers": 4850000, "Views": 3955207620, "Videos": 5754},
    {"Rank": 51, "Channel Title": "iggyazaleamusicVEVO", "Channel ID": "UCcdOEjqjiVAnUtEFZIRTlHg", "Subscribers": 4800000, "Views": 3877015430, "Videos": 93},
    {"Rank": 52, "Channel Title": "ColdFusion", "Channel ID": "UC4QZ_LsYcvcq7qOsOhpAX4A", "Subscribers": 4800000, "Views": 477318709, "Videos": 497},
    {"Rank": 53, "Channel Title": "Prestige Clips", "Channel ID": "UCC-uu-OqgYEx52KYQ-nJLRw", "Subscribers": 4750000, "Views": 1204084287, "Videos": 790},
    {"Rank": 54, "Channel Title": "WadZee", "Channel ID": "UCRlEFn0L2G_DktbyvN0AZ5A", "Subscribers": 4730000, "Views": 632058771, "Videos": 249},
    {"Rank": 55, "Channel Title": "Moto Madness", "Channel ID": "UC5nVgiv6elz5GnS6MTr1tVA", "Subscribers": 4660000, "Views": 1554270487, "Videos": 2047},
    {"Rank": 56, "Channel Title": "Jalals", "Channel ID": "UCcf0WYfeIkecTLQ_GzkBu1w", "Subscribers": 4640000, "Views": 297358162, "Videos": 22},
    {"Rank": 57, "Channel Title": "Andy Cooks", "Channel ID": "UCqNkn5PNeSqbQTAR5RP-L-Q", "Subscribers": 4600000, "Views": 2252594369, "Videos": 865},
    {"Rank": 74, "Channel Title": "Halfbrick Studios", "Channel ID": "UC_aCDTKgWQHfRC4gb9oE37g", "Subscribers": 3630000, "Views": 1063820810, "Videos": 1514},
    {"Rank": 75, "Channel Title": "LT.LICKME", "Channel ID": "UCfDuOF_6Mk-S1UJZoky15Og", "Subscribers": 3590000, "Views": 333663454, "Videos": 140},
    {"Rank": 76, "Channel Title": "Funformi", "Channel ID": "UCZOnSuO8tWFXLp8a828lgtA", "Subscribers": 3550000, "Views": 2391532195, "Videos": 226},
    {"Rank": 77, "Channel Title": "Grace's World", "Channel ID": "UC03GdYOZbnLQAPDXmjc6W9g", "Subscribers": 3520000, "Views": 4276636838, "Videos": 535},
    {"Rank": 78, "Channel Title": "Ash Magic", "Channel ID": "UCtaMRYGIXKhRpI86D2CqTEA", "Subscribers": 3510000, "Views": 4029273805, "Videos": 1857},
    {"Rank": 79, "Channel Title": "superwog1", "Channel ID": "UCQr98dS-5M_1xILTm4HAk-A", "Subscribers": 3470000, "Views": 487050535, "Videos": 67},
    {"Rank": 80, "Channel Title": "Wolfychu", "Channel ID": "UC_nEHeUEVNY5ZYLRWg8KoZQ", "Subscribers": 3380000, "Views": 437332559, "Videos": 174},
    {"Rank": 81, "Channel Title": "Kyutie", "Channel ID": "UCR6g32TTJcIRwn71M9lPd-g", "Subscribers": 3370000, "Views": 1163079599, "Videos": 3490},
    {"Rank": 82, "Channel Title": "Slapped Ham", "Channel ID": "UCw4ccFtBN7dhQBcHmE0qylg", "Subscribers": 3330000, "Views": 1014839957, "Videos": 1375},
    {"Rank": 83, "Channel Title": "Jason Stephenson - Sleep Meditation Music", "Channel ID": "UCqPYhcdFgrlUXiGmPRAej1w", "Subscribers": 3320000, "Views": 902354680, "Videos": 936},
    {"Rank": 84, "Channel Title": "Lauren Curtis", "Channel ID": "UCXbQzhqSvgVZTUyi1T4AU3w", "Subscribers": 3320000, "Views": 319653154, "Videos": 454},
    {"Rank": 85, "Channel Title": "ArtSpear Entertainment", "Channel ID": "UCmv8PJ2JcIsHQ-2ivtziszQ", "Subscribers": 3250000, "Views": 872129442, "Videos": 313},
    {"Rank": 86, "Channel Title": "Ben Lionel Scott", "Channel ID": "UCgkKA7xEOoBQNpC5TJxPLiw", "Subscribers": 3150000, "Views": 331555876, "Videos": 836},
    {"Rank": 87, "Channel Title": "Code Bullet", "Channel ID": "UC0e3QhIYukixgh5VVpKHH9Q", "Subscribers": 3130000, "Views": 252009404, "Videos": 61},
    {"Rank": 88, "Channel Title": "Vin", "Channel ID": "UCk8-8rY4q0cV1sOuSbVC_hg", "Subscribers": 3090000, "Views": 1941754250, "Videos": 459},
    {"Rank": 89, "Channel Title": "Ryan Williams", "Channel ID": "UC8DjAI26daPKmdO11zfpREw", "Subscribers": 3020000, "Views": 918561459, "Videos": 641},
    {"Rank": 90, "Channel Title": "MyCupcakeAddiction", "Channel ID": "UCxytOEPP99jj8mqVGAO7haQ", "Subscribers": 3010000, "Views": 456809243, "Videos": 489},
    {"Rank": 91, "Channel Title": "maxmoefoe", "Channel ID": "UCny_vGt2N7_QJ5qBOAHxlcw", "Subscribers": 2960000, "Views": 299860432, "Videos": 144},
    {"Rank": 92, "Channel Title": "HeyImBee", "Channel ID": "UC3otv50sBsnMrFbZNwawApQ", "Subscribers": 2950000, "Views": 270976453, "Videos": 95},
    {"Rank": 93, "Channel Title": "Tommy Craze", "Channel ID": "UC_EuakPoEj8zS-vFHrDmkwg", "Subscribers": 2930000, "Views": 438758213, "Videos": 212},
    {"Rank": 94, "Channel Title": "VaatiVidya", "Channel ID": "UCe0DNp0mKMqrYVaTundyr9w", "Subscribers": 2920000, "Views": 631066537, "Videos": 365},
    {"Rank": 95, "Channel Title": "Blender Guru", "Channel ID": "UCOKHwx1VCdgnxwbjyb9Iu1g", "Subscribers": 2920000, "Views": 180299867, "Videos": 220},
    {"Rank": 96, "Channel Title": "Kawaii Kunicorn", "Channel ID": "UC58otONbfRjWcYjlJvHaYfw", "Subscribers": 2900000, "Views": 1454815988, "Videos": 680},
    {"Rank": 97, "Channel Title": "MBC PD수첩", "Channel ID": "UCawCv9kO2UXbTtsK4EammRQ", "Subscribers": 940000, "Views": 481410474, "Videos": 2796},
    {"Rank": 98, "Channel Title": "Emkay", "Channel ID": "UCX-EhyoNi5sm7sijOg8TA_g", "Subscribers": 15300, "Views": 586247, "Videos": 37},
    {"Rank": 99, "Channel Title": "SAINTOffiziell", "Channel ID": "UC_3_YRBl9FIH319DWM3lRWQ", "Subscribers": 4620, "Views": 817337, "Videos": 7},
    {"Rank": 100, "Channel Title": "Sam Green", "Channel ID": "UCQFaWDcSiEbKy-fZ7CJRtlQ", "Subscribers": 5, "Views": 2960, "Videos": 10}
]

# Create a DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
print(df)

# Export the DataFrame to an Excel file
df.to_excel('top_100_australian_youtube_channels_from_65.xlsx', index=False)
print(os.getcwd())
# Out:
#     Rank               Channel Title                Channel ID  Subscribers  \
# 0      1  Bounce Patrol - Kids Songs  UC56cowXhoqRWHeqfSJkIQaA     29100000
# 1      2                  Chloe Ting  UCCgLoMYIyP0U56dEhEL1wXQ     25200000
# 2      3                   LazarBeam  UCw1SQ6QRRtfAhrN_cjkrOgA     21900000
# 3      4              How Ridiculous  UC5f5IV0Bf79YLp_p9nfInRA     21400000
# 4      5                         CKN  UCfaZw8XH_zmAVkBst_MPD6w     18800000
# ..   ...                         ...                       ...          ...
# 95    96             Kawaii Kunicorn  UC58otONbfRjWcYjlJvHaYfw      2900000
# 96    97                    MBC PD수첩  UCawCv9kO2UXbTtsK4EammRQ       940000
# 97    98                       Emkay  UCX-EhyoNi5sm7sijOg8TA_g        15300
# 98    99              SAINTOffiziell  UC_3_YRBl9FIH319DWM3lRWQ         4620
# 99   100                   Sam Green  UCQFaWDcSiEbKy-fZ7CJRtlQ            5
#
#           Views  Videos
# 0   22391924134     370
# ...
